# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pylab

# %%
x = np.linspace(0,10,100)
k = 1
plt.plot(x, np.cos(k*x))

k = 2
cos2 = plt.plot(x, np.cos(k*x))

pylab.legend ( ("cos(x)", "cos(2x)") )
